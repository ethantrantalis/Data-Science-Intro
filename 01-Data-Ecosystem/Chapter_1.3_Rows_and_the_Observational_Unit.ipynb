# %% [markdown]
# <a href="https://colab.research.google.com/github/ethantrantalis/Data-Science-Intro/blob/master/01-Data-Ecosystem/Chapter_1.3_Rows_and_the_Observational_Unit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rows and the Observational Unit
#
# Recall that the rows of a tabular data set represent observations. Whenever you encounter a new (tabular) data
# set, the first question you should ask yourself is
#
# > "What is the observational unit?"
#
# In other words, what does each row of the
# `DataFrame` represent? In the case of
# the OKCupid data set in the previous section, the observational unit was clearly an OKCupid user. But it is not always so obvious what the observational unit is.
#
# For example, consider the Framingham Heart Study data set, which is available at https://dlsun.github.io/pods/data/framingham_long.csv.
# This data comes from a study of men and women in
# the town of Framingham, Massachusetts, which has enrolled
# thousands of patients since it began in 1948 and is still ongoing. The goal of the study is to identify risk factors for cardivascular disease (CVD) by following the subjects over time. The data set that we will analyze was collected on 4,434 subjects between 1956 and 1968. A description of the data set is available [here](https://biolincc.nhlbi.nih.gov/media/teachingstudies/FHS_Teaching_Longitudinal_Data_Documentation.pdf).
#
# You might guess that the observational unit is a subject. Let's see if that guess is correct.

# %%
import pandas as pd

data_dir = "https://dlsun.github.io/pods/data/"
df_framingham = pd.read_csv(data_dir + "framingham_long.csv")
df_framingham.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# 1     6438     8766     8766
# 2     8766     8766     8766
# 3     8766     8766     8766
# 4     8766     8766     8766
#
# [5 rows x 39 columns]

# %% [markdown]
# Each `RANDID` corresponds to a unique subject in the study, but each subject appears multiple times in the data set. That is because this is a longitudinal study; each subject was measured at multiple points during their lifetime. So the observational unit in the Framingham Heart Study data set is a _measurement_ of a subject at a point in time.
#
# If there is a variable or a set of variables in the data set that uniquely identifies the observational unit, then it is customary to make those variables the index the `DataFrame`. In the Framingham data set, `RANDID` and `TIME` uniquely identify the observational unit, so we move these columns to the index. (Notice that we specify `inplace=True` so that `.set_index()` modifies the existing `DataFrame` rather than returning a new one.)

# %%
df_framingham.set_index(["RANDID", "TIME"], inplace=True)
df_framingham.head()
# Out:
#              SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# RANDID TIME
# 2448   0       1    195.0   39  106.0   70.0         0      0.0  26.97
#        4628    1    209.0   52  121.0   66.0         0      0.0    NaN
# 6238   0       2    250.0   46  121.0   81.0         0      0.0  28.73
#        2156    2    260.0   52  105.0   69.5         0      0.0  29.43
#        4344    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#              DIABETES  BPMEDS  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  \
# RANDID TIME                    ...
# 2448   0            0     0.0  ...    1         0    8766    6438      6438
#        4628         0     0.0  ...    1         0    8766    6438      6438
# 6238   0            0     0.0  ...    0         0    8766    8766      8766
#        2156         0     0.0  ...    0         0    8766    8766      8766
#        4344         0     0.0  ...    0         0    8766    8766      8766
#
#              TIMECHD  TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# RANDID TIME
# 2448   0        6438      8766     6438     8766     8766
#        4628     6438      8766     6438     8766     8766
# 6238   0        8766      8766     8766     8766     8766
#        2156     8766      8766     8766     8766     8766
#        4344     8766      8766     8766     8766     8766
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Selecting Rows
#
# We can select an individual row from a `DataFrame` using its label in the index. For example, the fourth row in the Framingham data set above has label `(6238, 2156)`. The `.loc` attribute of the `DataFrame` is used to select a row by its label.

# %%
row = df_framingham.loc[(6238, 2156)]
row
# Out:
# SEX            2.00
# TOTCHOL      260.00
# AGE           52.00
# SYSBP        105.00
# DIABP         69.50
# CURSMOKE       0.00
# CIGPDAY        0.00
# BMI           29.43
# DIABETES       0.00
# BPMEDS         0.00
# HEARTRTE      80.00
# GLUCOSE       86.00
# educ           2.00
# PREVCHD        0.00
# PREVAP         0.00
# PREVMI         0.00
# PREVSTRK       0.00
# PREVHYP        0.00
# PERIOD         2.00
# HDLC            NaN
# LDLC            NaN
# DEATH          0.00
# ANGINA         0.00
# HOSPMI         0.00
# MI_FCHD        0.00
# ANYCHD         0.00
# STROKE         0.00
# CVD            0.00
# HYPERTEN       0.00
# TIMEAP      8766.00
# TIMEMI      8766.00
# TIMEMIFC    8766.00
# TIMECHD     8766.00
# TIMESTRK    8766.00
# TIMECVD     8766.00
# TIMEDTH     8766.00
# TIMEHYP     8766.00
# Name: (6238, 2156), dtype: float64

# %% [markdown]
# We can also select a row by its position using the `.iloc` attribute. Keeping in mind that the first row is actually row 0, the fourth row could also be extracted as:

# %%
df_framingham.iloc[3]
# Out:
# SEX            2.00
# TOTCHOL      260.00
# AGE           52.00
# SYSBP        105.00
# DIABP         69.50
# CURSMOKE       0.00
# CIGPDAY        0.00
# BMI           29.43
# DIABETES       0.00
# BPMEDS         0.00
# HEARTRTE      80.00
# GLUCOSE       86.00
# educ           2.00
# PREVCHD        0.00
# PREVAP         0.00
# PREVMI         0.00
# PREVSTRK       0.00
# PREVHYP        0.00
# PERIOD         2.00
# HDLC            NaN
# LDLC            NaN
# DEATH          0.00
# ANGINA         0.00
# HOSPMI         0.00
# MI_FCHD        0.00
# ANYCHD         0.00
# STROKE         0.00
# CVD            0.00
# HYPERTEN       0.00
# TIMEAP      8766.00
# TIMEMI      8766.00
# TIMEMIFC    8766.00
# TIMECHD     8766.00
# TIMESTRK    8766.00
# TIMECVD     8766.00
# TIMEDTH     8766.00
# TIMEHYP     8766.00
# Name: (6238, 2156), dtype: float64

# %% [markdown]
# Notice that a single row from a `DataFrame` is no longer a `DataFrame` but a different data structure, called a `Series`.

# %%
type(row)
# Out:
# pandas.core.series.Series

# %% [markdown]
# We can also select multiple rows by passing a _list_ of labels or positions to `.loc` and `.iloc`, respectively.

# %%
rows = df_framingham.loc[[(2448, 4628), (6238, 2156)]]
rows
# Out:
#              SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# RANDID TIME
# 2448   4628    1    209.0   52  121.0   66.0         0      0.0    NaN
# 6238   2156    2    260.0   52  105.0   69.5         0      0.0  29.43
#
#              DIABETES  BPMEDS  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  \
# RANDID TIME                    ...
# 2448   4628         0     0.0  ...    1         0    8766    6438      6438
# 6238   2156         0     0.0  ...    0         0    8766    8766      8766
#
#              TIMECHD  TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# RANDID TIME
# 2448   4628     6438      8766     6438     8766     8766
# 6238   2156     8766      8766     8766     8766     8766
#
# [2 rows x 37 columns]

# %%
df_framingham.iloc[[1, 3]]
# Out:
#              SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# RANDID TIME
# 2448   4628    1    209.0   52  121.0   66.0         0      0.0    NaN
# 6238   2156    2    260.0   52  105.0   69.5         0      0.0  29.43
#
#              DIABETES  BPMEDS  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  \
# RANDID TIME                    ...
# 2448   4628         0     0.0  ...    1         0    8766    6438      6438
# 6238   2156         0     0.0  ...    0         0    8766    8766      8766
#
#              TIMECHD  TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# RANDID TIME
# 2448   4628     6438      8766     6438     8766     8766
# 6238   2156     8766      8766     8766     8766     8766
#
# [2 rows x 37 columns]

# %% [markdown]
# Notice that when we select multiple rows, we get a `DataFrame` back.

# %%
type(rows)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# So a `Series` is used to store a single observation (across multiple variables), while a `DataFrame` is used to store multiple observations (across multiple variables).

# %% [markdown]
# If selecting consecutive rows, we can use Python's `slice` notation. For example, the code below selects all rows from the fourth row, up to (but not including) the tenth row.

# %%
df_framingham.iloc[3:9]
# Out:
#              SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# RANDID TIME
# 6238   2156    2    260.0   52  105.0   69.5         0      0.0  29.43
#        4344    2    237.0   58  108.0   66.0         0      0.0  28.50
# 9428   0       1    245.0   48  127.5   80.0         1     20.0  25.34
#        2199    1    283.0   54  141.0   89.0         1     30.0  25.34
# 10552  0       2    225.0   61  150.0   95.0         1     30.0  28.58
#        1977    2    232.0   67  183.0  109.0         1     20.0  30.18
#
#              DIABETES  BPMEDS  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  \
# RANDID TIME                    ...
# 6238   2156         0     0.0  ...    0         0    8766    8766      8766
#        4344         0     0.0  ...    0         0    8766    8766      8766
# 9428   0            0     0.0  ...    0         0    8766    8766      8766
#        2199         0     0.0  ...    0         0    8766    8766      8766
# 10552  0            0     0.0  ...    1         1    2956    2956      2956
#        1977         0     0.0  ...    1         1    2956    2956      2956
#
#              TIMECHD  TIMESTRK  TIMECVD  TIMEDTH  TIMEHYP
# RANDID TIME
# 6238   2156     8766      8766     8766     8766     8766
#        4344     8766      8766     8766     8766     8766
# 9428   0        8766      8766     8766     8766     8766
#        2199     8766      8766     8766     8766     8766
# 10552  0        2956      2089     2089     2956        0
#        1977     2956      2089     2089     2956        0
#
# [6 rows x 37 columns]

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1\. Suppose you want to extract just the fourth row from the Framingham data set, but you want the result to be a `DataFrame` instead of a `Series`. In other words, you want a `DataFrame` with a single row. Can you figure out how to accomplish this?

# %%
# YOUR CODE HERE
row = df_framingham.iloc[[4]]
type(row)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Questions 2-4 deal with the Titanic data set (https://dlsun.github.io/pods/data/titanic.csv) contains information about 2206 passengers and crew members that were aboard the RMS Titanic when it sank on April 15, 1912.

# %% [markdown]
# 2\. Read in the Titanic data set. What is the observational unit?

# %%
# YOUR CODE HERE
titanic = pd.read_csv("/content/titanic.csv")
titanic

# Observable unit seems to be people on titanic with the unique identifier being name
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
#             country  ticketno   fare  survived
# 0     United States    5547.0   7.11         0
# 1     United States    2673.0  20.05         0
# 2     United States    2673.0  20.05         0
# 3           England    2673.0  20.05         1
# 4            Norway  348125.0   7.13         1
# ...             ...       ...    ...       ...
# 2202        England       NaN    NaN         1
# 2203        England       NaN    NaN         1
# 2204        England       NaN    NaN         0
# 2205        England       NaN    NaN         0
# 2206        England       NaN    NaN         0
#
# [2207 rows x 9 columns]

# %% [markdown]
# 3\. What column seems to be appropriate index for this data set? Do you see any problems with using this column as the index? (_Hint:_ Try looking up "Kelly, Mr. James" or "Green, Mr. George" in this `DataFrame`.)

# %%
# YOUR CODE HERE

titanic.loc[titanic["name"] == "Kelly, Mr. James"]

titanic.loc[titanic["name"] == "Green, Mr. George"]

# Since there are multiple elements with the same name field we
# Out:
#                   name gender   age             class embarked  country  \
# 476  Green, Mr. George   male  20.0  engineering crew        S  England
# 477  Green, Mr. George   male  41.0               3rd        S  England
#
#      ticketno  fare  survived
# 476       NaN   NaN         0
# 477   21440.0  8.01         0

# %% [markdown]
# 4\. Regardless of your reservations in the previous question, make "name" the index of the `DataFrame`. Use this to extract a `DataFrame` containing information about the three members of the Widener family:
#   - Widener, Mr. George Dunton
#   - Widener, Mr. Harry Elkins
#   - Widener, Mrs. Eleanor
#
# What became of them? Using a search engine, what else can you learn about them?

# %%
# YOUR CODE HERE

titanic.loc[titanic["name"].str.contains("Widener")]
# Out:
#                             name  gender   age class embarked        country  \
# 1283  Widener, Mr. George Dunton    male  50.0   1st        S  United States
# 1284   Widener, Mr. Harry Elkins    male  27.0   1st        S  United States
# 1285       Widener, Mrs. Eleanor  female  50.0   1st        S  United States
#
#       ticketno   fare  survived
# 1283  113503.0  211.1         0
# 1284  113503.0  211.1         0
# 1285  113503.0  211.1         1
